# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import tensorflow_decision_forests as tfdf
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import math
import warnings
warnings.filterwarnings(action="ignore")
# default figure size in this notebook
plt.rcParams['figure.figsize'] = (10,10)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Load a dataset into a Pandas DataFrame

# %%
train_proteins = pd.read_csv("/train_proteins.csv")
train_peptides = pd.read_csv("/train_peptides.csv")
train_clinical = pd.read_csv("/train_clinical_data.csv")
train_supplemental_clinical = pd.read_csv('/supplemental_clinical_data.csv')
train_clinical = train_clinical.append(train_supplemental_clinical, ignore_index=True)

# %% [markdown]
# # train_clinical NAN

# %%
from sklearn.impute import KNNImputer

# Select the variables with missing values
cols_to_impute = train_clinical[['updrs_1', 'updrs_2', 'updrs_3', 'updrs_4']]

# Impute missing values using KNN imputation
imputer = KNNImputer(n_neighbors=5)
imputed_values = imputer.fit_transform(cols_to_impute)

# Replace original variables with imputed values
train_clinical[['updrs_1', 'updrs_2', 'updrs_3', 'updrs_4']] = imputed_values

# %% [markdown]
# # prepare protien and peptide dataframes

# %%
# Function to prepare dataset with all the steps mentioned above:
def prepare_dataset(train_proteins, train_peptides):
    # Step 1: Grouping 
    df_protein_grouped = train_proteins.groupby(['visit_id','UniProt'])['NPX'].mean().reset_index()
    df_peptide_grouped = train_peptides.groupby(['visit_id','Peptide'])['PeptideAbundance'].mean().reset_index()
    
    # Step 2: Pivoting
    df_protein = df_protein_grouped.pivot(index='visit_id',columns = 'UniProt', values = 'NPX').rename_axis(columns=None).reset_index()
    df_peptide = df_peptide_grouped.pivot(index='visit_id',columns = 'Peptide', values = 'PeptideAbundance').rename_axis(columns=None).reset_index()
    
    # Step 3: Merging
    pro_pep_df = df_protein.merge(df_peptide, on = ['visit_id'], how = 'left')
    
    return pro_pep_df

pro_pep_df = prepare_dataset(train_proteins, train_peptides)

######################NAN

from sklearn.impute import KNNImputer

cols_to_impute = pro_pep_df.columns[pro_pep_df.isnull().any()].tolist()
cols_to_impute = pro_pep_df[cols_to_impute].select_dtypes(include='number').columns.tolist()

# Impute missing values using KNN imputation
imputer = KNNImputer(n_neighbors=5)
imputed_values = imputer.fit_transform(pro_pep_df[cols_to_impute])

# Replace original variables with imputed values
pro_pep_df[cols_to_impute] = imputed_values

#####################################
def split_dataset(dataset, test_ratio=0.20):
  test_indices = np.random.rand(len(dataset)) < test_ratio
  return dataset[~test_indices], dataset[test_indices]

def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

# Create an empty dictionary to store the models trained for each label.
model_dict = {}

# Create an empty dictionary to store the mse score of the models trained for each label.
mse_dict = {}

# Create an empty dictionary to store the sMAPE scores of the models trained for each label.
smape_dict = {}

FEATURES = [i for i in pro_pep_df.columns if i not in ["visit_id"]]
FEATURES.append("visit_month")

# List of target labels to loop through and train models
target = ["updrs_1", "updrs_2", "updrs_3", "updrs_4"]

# %% [markdown]
# # different models test

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.svm import LinearSVR, SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, BaggingRegressor, AdaBoostRegressor, ExtraTreesRegressor
import lightgbm as lgb
import xgboost as xgb
import time
# Loop through each label   
for label in target:
    print('#######################################################')
    print(f'model {label}')
    # Merge the label 'visit_id', 'patient_id', 'visit_month' and label columns from `train_clinical` 
    # data frame to `pro_prep_df` data frame on the `visit_id` column.
    dataset_df = pro_pep_df.merge(train_clinical[['visit_id', 'patient_id', 'visit_month', label]], on = ['visit_id'], how = 'left')

    # Drop null value label rows
    dataset_df = dataset_df.dropna(subset=[label])
    
    # Make a new copy of the FEATURES list we created previously. Add `label` to it.
    feature_list = FEATURES.copy() 
    feature_list.append(label)
    
    # Split the dataset into train and validation datasets.
    train_df, valid_df = split_dataset(dataset_df[feature_list])
    # Define the pipeline with default hyperparameter values

    random_state = 42
    # default params
    classifiers = [
        # models
        DummyRegressor(strategy="mean"),
        LinearRegression(),
        Ridge(random_state=random_state),
        Lasso(random_state=random_state),
        ElasticNet(random_state=random_state),
        KernelRidge(),
        SGDRegressor(random_state=random_state),

        LinearSVR(random_state=random_state),
        SVR(kernel="linear", gamma="scale"),
        SVR(kernel="rbf", gamma="scale"),
        SVR(kernel="poly", degree=2, gamma="scale"),
        SVR(kernel="sigmoid", gamma="scale"),

        DecisionTreeRegressor(random_state=random_state),
        RandomForestRegressor(random_state=random_state),

        BaggingRegressor(random_state=random_state),
        AdaBoostRegressor(random_state=random_state),
        ExtraTreesRegressor(random_state=random_state),
        GradientBoostingRegressor(random_state=random_state),
        lgb.LGBMRegressor(random_state=random_state),
        xgb.XGBRegressor(objective="reg:squarederror", random_state=random_state)
        ]

    clf_names = [
        "dummy",
        "linear",
        "ridge",
        "lasso",
        "elastic",
        "kernlrdg",
        "sgdreg",
        "linearsvr",
        "rbfsvr",
        "polysvr",
        "sigmoidsvr", 
        "knnreg"
        "decisiontree",
        "randomforest",
        "baggingreg",
        "adaboostreg",
        "extratreesreg", 
        "gbm", 
        "lgbm", 
        "xgboost"
    ]

    ## testing

    mse_dict = {}
    smape_dict = {}
    pipelines = []
    for clf, name in zip(classifiers, clf_names):
        pipeline = Pipeline([
            ('scaler', StandardScaler()),
            ('model', clf)
        ])
        pipelines.append((name, pipeline))
    # Iterate through each model in the pipeline
    for model_name, pipeline in pipelines:
        print(f'####################################################')
        print(f"Training model: {model_name}")

        # Start the timer
        start_time = time.time()

        # Fit the model on the training data
        pipeline.fit(train_df[FEATURES], train_df[label])
        print(f"Model {model_name} trained.")

        # Calculate the elapsed time
        elapsed_time = time.time() - start_time
        print(f"Training time for model {model_name}: {elapsed_time:.2f} seconds")

        # Make predictions on the validation data
        preds = pipeline.predict(valid_df[FEATURES])

        # Calculate the MSE score
        mse = mean_squared_error(valid_df[label], preds)
        print(f"Model {model_name} MSE score: {mse:.4f}")

        # Calculate the sMAPE score
        smape_score = smape(valid_df[label], preds)
        print(f"Model {model_name} sMAPE score: {smape_score:.4f}")

        # Store the MSE and sMAPE scores in their respective dictionaries
        mse_dict[model_name] = mse
        smape_dict[model_name] = smape_score


    # Store the results in a list of lists
    results = []
    for model_name, mse_score in mse_dict.items():
        results.append([model_name, f"{mse_score:.2f}", f"{smape_dict[model_name]:.2f}"])

    # Define the headers for the table
    headers = ["Model", "MSE", "sMAPE"]

    # Print the table
    results_df = pd.DataFrame(results, columns=headers)

    # Print the DataFrame
    print(results_df)

    # plot smape scores to compare
    smape_df = pd.DataFrame.from_dict(smape_dict, orient='index', columns=['sMAPE'])
    smape_df = smape_df.sort_values(by='sMAPE')

    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.barplot(x=smape_df.index, y="sMAPE", data=smape_df)
    plt.xlabel('Model')
    plt.ylabel('sMAPE')
    plt.title('sMAPE Scores for Regression Models')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()
# Out:
# #######################################################
# model updrs_1
# ####################################################
# Training model: dummy
# Model dummy trained.
# Training time for model dummy: 0.05 seconds
# Model dummy MSE score: 29.3014
# Model dummy sMAPE score: 70.8145
# ####################################################
# Training model: linear
# Model linear trained.
# Training time for model linear: 0.43 seconds
# Model linear MSE score: 99.6657
# Model linear sMAPE score: 106.3938
# ####################################################
# Training model: ridge
# Model ridge trained.
# Training time for model ridge: 0.17 seconds
# Model ridge MSE score: 84.5329
# Model ridge sMAPE score: 102.5841
# ####################################################
# Training model: lasso
# Model lasso trained.
# Training time for model lasso: 0.12 seconds
# Model lasso MSE score: 29.3014
# Model lasso sMAPE score: 70.8145
# ####################################################
# Training model: elastic
# Model elastic trained.
# Training time for model elastic: 0.13 seconds
# Model elastic MSE score: 28.2718
# Model elastic sMAPE score: 70.3755
# ####################################################
# Training model: kernlrdg
# Model kernlrdg trained.
# Training time for model kernlrdg: 0.19 seconds
# Model kernlrdg MSE score: 115.2015
# Model kernlrdg sMAPE score: 141.2593
# ####################################################
# Training model: sgdreg
# Model sgdreg trained.
# Training time for model sgdreg: 0.16 seconds
# Model sgdreg MSE score: 122777408980609885274112.0000
# Model sgdreg sMAPE score: 200.0000
# ####################################################
# Training model: linearsvr
# Model linearsvr trained.
# Training time for model linearsvr: 4.44 seconds
# Model linearsvr MSE score: 98.0328
# Model linearsvr sMAPE score: 105.9706
# ####################################################
# Training model: rbfsvr
# Model rbfsvr trained.
# Training time for model rbfsvr: 5.59 seconds
# Model rbfsvr MSE score: 93.8392
# Model rbfsvr sMAPE score: 104.7922
# ####################################################
# Training model: polysvr
# Model polysvr trained.
# Training time for model polysvr: 0.40 seconds
# Model polysvr MSE score: 27.6772
# Model polysvr sMAPE score: 68.6201
# ####################################################
# Training model: sigmoidsvr
# Model sigmoidsvr trained.
# Training time for model sigmoidsvr: 0.40 seconds
# Model sigmoidsvr MSE score: 28.3308
# Model sigmoidsvr sMAPE score: 69.1440
# ####################################################
# Training model: knnregdecisiontree
# Model knnregdecisiontree trained.
# Training time for model knnregdecisiontree: 0.44 seconds
# Model knnregdecisiontree MSE score: 30.4298
# Model knnregdecisiontree sMAPE score: 75.9572
# ####################################################
# Training model: randomforest
# Model randomforest trained.
# Training time for model randomforest: 1.16 seconds
# Model randomforest MSE score: 52.0180
# Model randomforest sMAPE score: 82.7939
# ####################################################
# Training model: baggingreg
# Model baggingreg trained.
# Training time for model baggingreg: 75.49 seconds
# Model baggingreg MSE score: 25.8660
# Model baggingreg sMAPE score: 67.6258
# ####################################################
# Training model: adaboostreg
# Model adaboostreg trained.
# Training time for model adaboostreg: 7.62 seconds
# Model adaboostreg MSE score: 26.4472
# Model adaboostreg sMAPE score: 68.2455
# ####################################################
# Training model: extratreesreg
# Model extratreesreg trained.
# Training time for model extratreesreg: 10.50 seconds
# Model extratreesreg MSE score: 28.1616
# Model extratreesreg sMAPE score: 70.3467
# ####################################################
# Training model: gbm
# Model gbm trained.
# Training time for model gbm: 18.06 seconds
# Model gbm MSE score: 24.0424
# Model gbm sMAPE score: 66.0111
# ####################################################
# Training model: lgbm
# Model lgbm trained.
# Training time for model lgbm: 32.32 seconds
# Model lgbm MSE score: 25.8416
# Model lgbm sMAPE score: 67.4716
# ####################################################
# Training model: xgboost
# Model xgboost trained.
# Training time for model xgboost: 7.16 seconds
# Model xgboost MSE score: 25.0893
# Model xgboost sMAPE score: 66.1397
#                  Model                          MSE   sMAPE
# 0                dummy                        29.30   70.81
# 1               linear                        99.67  106.39
# 2                ridge                        84.53  102.58
# 3                lasso                        29.30   70.81
# 4              elastic                        28.27   70.38
# 5             kernlrdg                       115.20  141.26
# 6               sgdreg  122777408980609885274112.00  200.00
# 7            linearsvr                        98.03  105.97
# 8               rbfsvr                        93.84  104.79
# 9              polysvr                        27.68   68.62
# 10          sigmoidsvr                        28.33   69.14
# 11  knnregdecisiontree                        30.43   75.96
# 12        randomforest                        52.02   82.79
# 13          baggingreg                        25.87   67.63
# 14         adaboostreg                        26.45   68.25
# 15       extratreesreg                        28.16   70.35
# 16                 gbm                        24.04   66.01
# 17                lgbm                        25.84   67.47
# 18             xgboost                        25.09   66.14
# #######################################################
# model updrs_2
# ####################################################
# Training model: dummy
# Model dummy trained.
# Training time for model dummy: 0.05 seconds
# Model dummy MSE score: 40.0247
# Model dummy sMAPE score: 94.6266
# ####################################################
# Training model: linear
# Model linear trained.
# Training time for model linear: 0.43 seconds
# Model linear MSE score: 133.9331
# Model linear sMAPE score: 130.1596
# ####################################################
# Training model: ridge
# Model ridge trained.
# Training time for model ridge: 0.19 seconds
# Model ridge MSE score: 100.3024
# Model ridge sMAPE score: 125.0015
# ####################################################
# Training model: lasso
# Model lasso trained.
# Training time for model lasso: 0.17 seconds
# Model lasso MSE score: 39.1946
# Model lasso sMAPE score: 94.5025
# ####################################################
# Training model: elastic
# Model elastic trained.
# Training time for model elastic: 0.14 seconds
# Model elastic MSE score: 37.3940
# Model elastic sMAPE score: 94.5307
# ####################################################
# Training model: kernlrdg
# Model kernlrdg trained.
# Training time for model kernlrdg: 0.18 seconds
# Model kernlrdg MSE score: 128.6441
# Model kernlrdg sMAPE score: 151.3796
# ####################################################
# Training model: sgdreg
# Model sgdreg trained.
# Training time for model sgdreg: 1.43 seconds
# Model sgdreg MSE score: 58175684353344380928.0000
# Model sgdreg sMAPE score: 200.0000
# ####################################################
# Training model: linearsvr
# Model linearsvr trained.
# Training time for model linearsvr: 4.42 seconds
# Model linearsvr MSE score: 108.6601
# Model linearsvr sMAPE score: 124.9334
# ####################################################
# Training model: rbfsvr
# Model rbfsvr trained.
# Training time for model rbfsvr: 7.25 seconds
# Model rbfsvr MSE score: 106.8629
# Model rbfsvr sMAPE score: 124.6351
# ####################################################
# Training model: polysvr
# Model polysvr trained.
# Training time for model polysvr: 0.41 seconds
# Model polysvr MSE score: 39.1154
# Model polysvr sMAPE score: 97.6001
# ####################################################
# Training model: sigmoidsvr
# Model sigmoidsvr trained.
# Training time for model sigmoidsvr: 0.40 seconds
# Model sigmoidsvr MSE score: 38.4993
# Model sigmoidsvr sMAPE score: 98.0592
# ####################################################
# Training model: knnregdecisiontree
# Model knnregdecisiontree trained.
# Training time for model knnregdecisiontree: 0.45 seconds
# Model knnregdecisiontree MSE score: 38.5195
# Model knnregdecisiontree sMAPE score: 104.0741
# ####################################################
# Training model: randomforest
# Model randomforest trained.
# Training time for model randomforest: 1.21 seconds
# Model randomforest MSE score: 50.4798
# Model randomforest sMAPE score: 96.9041
# ####################################################
# Training model: baggingreg
# Model baggingreg trained.
# Training time for model baggingreg: 73.42 seconds
# Model baggingreg MSE score: 30.2552
# Model baggingreg sMAPE score: 91.6035
# ####################################################
# Training model: adaboostreg
# Model adaboostreg trained.
# Training time for model adaboostreg: 6.86 seconds
# Model adaboostreg MSE score: 33.5678
# Model adaboostreg sMAPE score: 94.3606
# ####################################################
# Training model: extratreesreg
# Model extratreesreg trained.
# Training time for model extratreesreg: 11.36 seconds
# Model extratreesreg MSE score: 33.8186
# Model extratreesreg sMAPE score: 91.9281
# ####################################################
# Training model: gbm
# Model gbm trained.
# Training time for model gbm: 17.59 seconds
# Model gbm MSE score: 28.0892
# Model gbm sMAPE score: 90.5926
# ####################################################
# Training model: lgbm
# Model lgbm trained.
# Training time for model lgbm: 33.64 seconds
# Model lgbm MSE score: 29.6928
# Model lgbm sMAPE score: 90.8100
# ####################################################
# Training model: xgboost
# Model xgboost trained.
# Training time for model xgboost: 7.47 seconds
# Model xgboost MSE score: 28.2694
# Model xgboost sMAPE score: 91.3685
#                  Model                      MSE   sMAPE
# 0                dummy                    40.02   94.63
# 1               linear                   133.93  130.16
# 2                ridge                   100.30  125.00
# 3                lasso                    39.19   94.50
# 4              elastic                    37.39   94.53
# 5             kernlrdg                   128.64  151.38
# 6               sgdreg  58175684353344380928.00  200.00
# 7            linearsvr                   108.66  124.93
# 8               rbfsvr                   106.86  124.64
# 9              polysvr                    39.12   97.60
# 10          sigmoidsvr                    38.50   98.06
# 11  knnregdecisiontree                    38.52  104.07
# 12        randomforest                    50.48   96.90
# 13          baggingreg                    30.26   91.60
# 14         adaboostreg                    33.57   94.36
# 15       extratreesreg                    33.82   91.93
# 16                 gbm                    28.09   90.59
# 17                lgbm                    29.69   90.81
# 18             xgboost                    28.27   91.37
# #######################################################
# model updrs_3
# ####################################################
# Training model: dummy
# Model dummy trained.
# Training time for model dummy: 0.05 seconds
# Model dummy MSE score: 211.6995
# Model dummy sMAPE score: 87.7303
# ####################################################
# Training model: linear
# Model linear trained.
# Training time for model linear: 0.42 seconds
# Model linear MSE score: 706.2361
# Model linear sMAPE score: 121.7676
# ####################################################
# Training model: ridge
# Model ridge trained.
# Training time for model ridge: 0.15 seconds
# Model ridge MSE score: 519.9891
# Model ridge sMAPE score: 114.0809
# ####################################################
# Training model: lasso
# Model lasso trained.
# Training time for model lasso: 0.17 seconds
# Model lasso MSE score: 197.0569
# Model lasso sMAPE score: 86.1302
# ####################################################
# Training model: elastic
# Model elastic trained.
# Training time for model elastic: 0.38 seconds
# Model elastic MSE score: 180.8798
# Model elastic sMAPE score: 84.8824
# ####################################################
# Training model: kernlrdg
# Model kernlrdg trained.
# Training time for model kernlrdg: 0.15 seconds
# Model kernlrdg MSE score: 864.7140
# Model kernlrdg sMAPE score: 149.8995
# ####################################################
# Training model: sgdreg
# Model sgdreg trained.
# Training time for model sgdreg: 1.15 seconds
# Model sgdreg MSE score: 83335989751373070336.0000
# Model sgdreg sMAPE score: 200.0000
# ####################################################
# Training model: linearsvr
# Model linearsvr trained.
# Training time for model linearsvr: 4.25 seconds
# Model linearsvr MSE score: 444.7310
# Model linearsvr sMAPE score: 112.0313
# ####################################################
# Training model: rbfsvr
# Model rbfsvr trained.
# Training time for model rbfsvr: 3.33 seconds
# Model rbfsvr MSE score: 442.4949
# Model rbfsvr sMAPE score: 111.5812
# ####################################################
# Training model: polysvr
# Model polysvr trained.
# Training time for model polysvr: 0.41 seconds
# Model polysvr MSE score: 200.0761
# Model polysvr sMAPE score: 87.8370
# ####################################################
# Training model: sigmoidsvr
# Model sigmoidsvr trained.
# Training time for model sigmoidsvr: 0.40 seconds
# Model sigmoidsvr MSE score: 206.5817
# Model sigmoidsvr sMAPE score: 88.3068
# ####################################################
# Training model: knnregdecisiontree
# Model knnregdecisiontree trained.
# Training time for model knnregdecisiontree: 0.44 seconds
# Model knnregdecisiontree MSE score: 195.3915
# Model knnregdecisiontree sMAPE score: 86.6397
# ####################################################
# Training model: randomforest
# Model randomforest trained.
# Training time for model randomforest: 1.01 seconds
# Model randomforest MSE score: 336.0550
# Model randomforest sMAPE score: 102.3903
# ####################################################
# Training model: baggingreg
# Model baggingreg trained.
# Training time for model baggingreg: 64.50 seconds
# Model baggingreg MSE score: 169.3326
# Model baggingreg sMAPE score: 83.1194
# ####################################################
# Training model: adaboostreg
# Model adaboostreg trained.
# Training time for model adaboostreg: 6.26 seconds
# Model adaboostreg MSE score: 192.2952
# Model adaboostreg sMAPE score: 85.2545
# ####################################################
# Training model: extratreesreg
# Model extratreesreg trained.
# Training time for model extratreesreg: 11.54 seconds
# Model extratreesreg MSE score: 185.9491
# Model extratreesreg sMAPE score: 85.7157
# ####################################################
# Training model: gbm
# Model gbm trained.
# Training time for model gbm: 18.41 seconds
# Model gbm MSE score: 161.1907
# Model gbm sMAPE score: 82.0766
# ####################################################
# Training model: lgbm
# Model lgbm trained.
# Training time for model lgbm: 33.69 seconds
# Model lgbm MSE score: 161.0736
# Model lgbm sMAPE score: 83.5418
# ####################################################
# Training model: xgboost
# Model xgboost trained.
# Training time for model xgboost: 7.29 seconds
# Model xgboost MSE score: 155.3508
# Model xgboost sMAPE score: 82.0955
#                  Model                      MSE   sMAPE
# 0                dummy                   211.70   87.73
# 1               linear                   706.24  121.77
# 2                ridge                   519.99  114.08
# 3                lasso                   197.06   86.13
# 4              elastic                   180.88   84.88
# 5             kernlrdg                   864.71  149.90
# 6               sgdreg  83335989751373070336.00  200.00
# 7            linearsvr                   444.73  112.03
# 8               rbfsvr                   442.49  111.58
# 9              polysvr                   200.08   87.84
# 10          sigmoidsvr                   206.58   88.31
# 11  knnregdecisiontree                   195.39   86.64
# 12        randomforest                   336.06  102.39
# 13          baggingreg                   169.33   83.12
# 14         adaboostreg                   192.30   85.25
# 15       extratreesreg                   185.95   85.72
# 16                 gbm                   161.19   82.08
# 17                lgbm                   161.07   83.54
# 18             xgboost                   155.35   82.10
# #######################################################
# model updrs_4
# ####################################################
# Training model: dummy
# Model dummy trained.
# Training time for model dummy: 0.05 seconds
# Model dummy MSE score: 6.9867
# Model dummy sMAPE score: 144.5853
# ####################################################
# Training model: linear
# Model linear trained.
# Training time for model linear: 0.40 seconds
# Model linear MSE score: 20.8006
# Model linear sMAPE score: 166.3700
# ####################################################
# Training model: ridge
# Model ridge trained.
# Training time for model ridge: 0.18 seconds
# Model ridge MSE score: 17.3856
# Model ridge sMAPE score: 164.3302
# ####################################################
# Training model: lasso
# Model lasso trained.
# Training time for model lasso: 0.13 seconds
# Model lasso MSE score: 6.9867
# Model lasso sMAPE score: 144.5853
# ####################################################
# Training model: elastic
# Model elastic trained.
# Training time for model elastic: 0.11 seconds
# Model elastic MSE score: 6.9867
# Model elastic sMAPE score: 144.5853
# ####################################################
# Training model: kernlrdg
# Model kernlrdg trained.
# Training time for model kernlrdg: 0.15 seconds
# Model kernlrdg MSE score: 19.7241
# Model kernlrdg sMAPE score: 177.9033
# ####################################################
# Training model: sgdreg
# Model sgdreg trained.
# Training time for model sgdreg: 0.16 seconds
# Model sgdreg MSE score: 102648767236615106985984.0000
# Model sgdreg sMAPE score: 200.0000
# ####################################################
# Training model: linearsvr
# Model linearsvr trained.
# Training time for model linearsvr: 4.27 seconds
# Model linearsvr MSE score: 20.3973
# Model linearsvr sMAPE score: 165.8238
# ####################################################
# Training model: rbfsvr
# Model rbfsvr trained.
# Training time for model rbfsvr: 4.56 seconds
# Model rbfsvr MSE score: 18.0834
# Model rbfsvr sMAPE score: 164.2251
# ####################################################
# Training model: polysvr
# Model polysvr trained.
# Training time for model polysvr: 0.37 seconds
# Model polysvr MSE score: 7.5279
# Model polysvr sMAPE score: 160.7304
# ####################################################
# Training model: sigmoidsvr
# Model sigmoidsvr trained.
# Training time for model sigmoidsvr: 0.35 seconds
# Model sigmoidsvr MSE score: 7.9037
# Model sigmoidsvr sMAPE score: 163.3331
# ####################################################
# Training model: knnregdecisiontree
# Model knnregdecisiontree trained.
# Training time for model knnregdecisiontree: 0.39 seconds
# Model knnregdecisiontree MSE score: 21.6247
# Model knnregdecisiontree sMAPE score: 163.7372
# ####################################################
# Training model: randomforest
# Model randomforest trained.
# Training time for model randomforest: 3.13 seconds
# Model randomforest MSE score: 13.3737
# Model randomforest sMAPE score: 113.6028
# ####################################################
# Training model: baggingreg
# Model baggingreg trained.
# Training time for model baggingreg: 197.33 seconds
# Model baggingreg MSE score: 7.5417
# Model baggingreg sMAPE score: 145.2725
# ####################################################
# Training model: adaboostreg
# Model adaboostreg trained.
# Training time for model adaboostreg: 19.20 seconds
# Model adaboostreg MSE score: 7.9309
# Model adaboostreg sMAPE score: 142.2033
# ####################################################
# Training model: extratreesreg
# Model extratreesreg trained.
# Training time for model extratreesreg: 10.37 seconds
# Model extratreesreg MSE score: 7.2939
# Model extratreesreg sMAPE score: 140.0085
# ####################################################
# Training model: gbm
# Model gbm trained.
# Training time for model gbm: 22.12 seconds
# Model gbm MSE score: 7.3588
# Model gbm sMAPE score: 145.0549
# ####################################################
# Training model: lgbm
# Model lgbm trained.
# Training time for model lgbm: 31.76 seconds
# Model lgbm MSE score: 6.6962
# Model lgbm sMAPE score: 144.1991
# ####################################################
# Training model: xgboost
# Model xgboost trained.
# Training time for model xgboost: 7.37 seconds
# Model xgboost MSE score: 6.5446
# Model xgboost sMAPE score: 145.9444
#                  Model                          MSE   sMAPE
# 0                dummy                         6.99  144.59
# 1               linear                        20.80  166.37
# 2                ridge                        17.39  164.33
# 3                lasso                         6.99  144.59
# 4              elastic                         6.99  144.59
# 5             kernlrdg                        19.72  177.90
# 6               sgdreg  102648767236615106985984.00  200.00
# 7            linearsvr                        20.40  165.82
# 8               rbfsvr                        18.08  164.23
# 9              polysvr                         7.53  160.73
# 10          sigmoidsvr                         7.90  163.33
# 11  knnregdecisiontree                        21.62  163.74
# 12        randomforest                        13.37  113.60
# 13          baggingreg                         7.54  145.27
# 14         adaboostreg                         7.93  142.20
# 15       extratreesreg                         7.29  140.01
# 16                 gbm                         7.36  145.05
# 17                lgbm                         6.70  144.20
# 18             xgboost                         6.54  145.94

# %% [markdown]
# # train best model each

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor
from sklearn.svm import LinearSVR, SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, BaggingRegressor, AdaBoostRegressor, ExtraTreesRegressor
import lightgbm as lgb
import xgboost as xgb
import time
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.utils import shuffle
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer

def smape_score(y_true, y_pred):
    diff = np.abs(y_true - y_pred)
    denom = (np.abs(y_true) + np.abs(y_pred)) / 2
    return np.mean(diff / denom) * 100

cv_smape_dict = {}

random_state = 42

classifiers = [
        # models
        lgb.LGBMRegressor(random_state=random_state),
        GradientBoostingRegressor(random_state=random_state),
        RandomForestRegressor(random_state=random_state),
        xgb.XGBRegressor(objective="reg:squarederror", random_state=random_state)      
        ]

mse_dict = {}
mae_dict = {}
r2_dict = {}
adj_r2_dict = {}
smape_dict = {}
pipelines = []
for clf, name in zip(classifiers, target):
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('model', clf)
    ])
    pipelines.append((name, pipeline))

# Iterate through each model in the pipeline
for label, pipeline in pipelines:
    print('#######################################################')
    print(f'model {label}')
    # Merge the label 'visit_id', 'patient_id', 'visit_month' and label columns from `train_clinical` 
    # data frame to `pro_prep_df` data frame on the `visit_id` column.
    dataset_df = pro_pep_df.merge(train_clinical[['visit_id', 'patient_id', 'visit_month', label]], on = ['visit_id'], how = 'left')

    # Drop null value label rows
    dataset_df = dataset_df.dropna(subset=[label])

    # Make a new copy of the FEATURES list we created previously. Add `label` to it.
    feature_list = FEATURES.copy() 
    feature_list.append(label)

    # Split the dataset into train and validation datasets.
    train_df, valid_df = split_dataset(dataset_df[feature_list])
    # Define the pipeline with default hyperparameter values

    random_state = 42
    # default params

    # Start the timer
    start_time = time.time()

    # Fit the model on the training data
    pipeline.fit(train_df[FEATURES], train_df[label])
    print(f"Model {label} trained.")

    # Calculate the elapsed time
    elapsed_time = time.time() - start_time
    print(f"Training time for model {label}: {elapsed_time:.2f} seconds")

    # Make predictions on the validation data
    preds = pipeline.predict(valid_df[FEATURES])

    # Calculate the sMAPE score
    smape_dict[label] = smape(valid_df[label], preds.flatten())

    mae = mean_absolute_error(valid_df[label], preds.flatten())
    mse = mean_squared_error(valid_df[label], preds.flatten())
    r2 = r2_score(valid_df[label], preds.flatten())
    
    #display adjusted R-squared
    X = valid_df[FEATURES]
    y = valid_df[label]
    adj_r2 = 1 - (1-pipeline.score(X, y))*(len(y)-1)/(len(y)-X.shape[1]-1) 

    mse_dict[label] = mse
    mae_dict[label] = mae
    r2_dict[label] = r2
    adj_r2_dict[label] = adj_r2

    # cv for sMAPE
    cv_smape = cross_val_score(pipeline, train_df[FEATURES], train_df[label], scoring=make_scorer(smape_score), cv=5)
    cv_smape_dict[label] = cv_smape
    
    # Print evaluation metrics
    print(f"Evaluation Metrics for '{label}':")
    print(f"SMAPE: {smape_dict[label]}")
    print(f"MAE: {mae}")
    print(f"MSE: {mse}")
    print(f"R^2: {r2}")
    print(f"Adjusted R^2: {adj_r2}")
    print("------------------------------------------------------------------------------------------------------------------")
    # Store the MSE and sMAPE scores in their respective dictionaries

    # Store the model
    model_dict[label] = clf   
#####################################
print("\nAverage sMAPE", sum(smape_dict.values())/4)
print("Average MAE", sum(mae_dict.values())/4)
print("Average MSE", sum(mse_dict.values())/4)
print("Average R^2", sum(r2_dict.values())/4)
print("Average Adjusted R^2", sum(adj_r2_dict.values())/4)
print("\nAverage mse", sum(mse_dict.values())/4)
# Out:
# #######################################################
# model updrs_1
# Model updrs_1 trained.
# Training time for model updrs_1: 7.51 seconds
# Evaluation Metrics for 'updrs_1':
# SMAPE: 67.31256742229513
# MAE: 3.89887207153284
# MSE: 27.33197718802631
# R^2: 0.19124558715745787
# Adjusted R^2: 1.1585158649171383
# ------------------------------------------------------------------------------------------------------------------
# #######################################################
# model updrs_2
# Model updrs_2 trained.
# Training time for model updrs_2: 32.88 seconds
# Evaluation Metrics for 'updrs_2':
# SMAPE: 92.64771215848509
# MAE: 4.255492764304845
# MSE: 32.237394970885525
# R^2: 0.1602596759670738
# Adjusted R^2: 1.186132431373999
# ------------------------------------------------------------------------------------------------------------------
# #######################################################
# model updrs_3
# Model updrs_3 trained.
# Training time for model updrs_3: 64.51 seconds

# %% [markdown]
# ## cross validation with SMAPE

# %%
print("Cross-Validation sMAPE:")
for model_name, cv_smape in cv_smape_dict.items():
    smape_dict[model_name] = cv_smape.mean()
    print(f"{model_name}: {cv_smape.mean()}")
print("\nAverage sMAPE", sum(smape_dict.values())/4)
